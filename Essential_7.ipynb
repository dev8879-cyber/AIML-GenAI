# %% [markdown]
# <a href="https://colab.research.google.com/github/dev8879-cyber/AIML-GenAI/blob/main/Essential_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5,1):
  print(i)

# %%
for i in range(5,1,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
for i in range(1,10,3):
  print(i)
# Out:
# 1
# 4
# 7

# %%
name="data";
for ch in name:
  if ch!="a":
    print(ch)
# Out:
# d
# t

# %%
i=1;
while(i<=7):
  print(i);
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
i=1;
while i<=7:
  print(i,"hi")
  i=i+1;
# Out:
# 1 hi
# 2 hi
# 3 hi
# 4 hi
# 5 hi
# 6 hi
# 7 hi

# %%
i=1
while(i<10):
  print(i)
  i+=2
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
sum=0;
for i in range(1,11,1):
  sum+=i;
print(sum)
# Out:
# 55

# %%
i=1;
sum=0;
while(i<=10):
  sum=sum+i;
  i+=1;
print(sum)
# Out:
# 55

# %%
i=1;
while(i<=10):
  print("5 *",i,"=",5*i)
  i+=1;
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
