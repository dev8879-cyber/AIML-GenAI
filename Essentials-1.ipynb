# %% [markdown]
# <a href="https://colab.research.google.com/github/dev8879-cyber/AIML-GenAI/blob/main/Essentials-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lecture 1

# %%
print("Hello World!!")
# Out:
# Hello World!!

# %%
print("A","B","C")
# Out:
# A B C

# %%
print("a")
print("b")
print("c")
# Out:
# a
# b
# c

# %%
print(3+2)
# Out:
# 5

# %%
print("3+2")
# Out:
# 3+2
