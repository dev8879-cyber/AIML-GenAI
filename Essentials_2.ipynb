# %% [markdown]
# <a href="https://colab.research.google.com/github/dev8879-cyber/AIML-GenAI/blob/main/Essentials_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lecture 2:

# %% [markdown]
# ##Comments:

# %%
print("Hello")
# This statement will print Hello
# Out:
# Hello

# %%
# Hello, I am a comment. Used to describe codes

# %%
print("Python")
print("SQL")
# Out:
# Python
# SQL

# %% [markdown]
# ##Variables

# %%
city="Vadodara"
id=11

# %%
print(city)
print(id)
# Out:
# Vadodara
# 11

# %% [markdown]
# ##Data types:

# %%
type("4")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(6.8)
# Out:
# float

# %% [markdown]
# ##Taking input:

# %%
name=input()
# Out:
# Dev

# %%
print(name)
# Out:
# Dev

# %%
name=input("Enter your name:");
# Out:
# Enter your name:Dev

# %%
print(name)
# Out:
# Dev

# %% [markdown]
# ##Print Sum of two numbers by taking two inputs:

# %%
a=input("Enter 1st number:") #Input as string
b=input("Enter 2nd number:")#Input as String
print(a+b);# String Concatenation
# Out:
# Enter 1st number:2
# Enter 2nd number:4
# 24

# %% [markdown]
# ###input()--> Always in string format

# %% [markdown]
# ##TypeCasting:

# %%
age="20"
new_age=int(age);
type(age)
type(new_age)
# Out:
# int

# %%
a=int(input("Enter number 1:"));
b=int(input("Enter number 2:"));
c=print(a+b);
print(c);
# Out:
# Enter number 1:3
# Enter number 2:4
# 7
# None

# %%
d=print("Devdatt");
print(d)
# Out:
# Devdatt
# None

# %% [markdown]
# ###Taking birthday year as input and print age:

# %%
b_year=int(input("Enter birth year:"));
age=2026-b_year;
print(age)
# Out:
# Enter birth year:2005
# 21

# %% [markdown]
# ###Taking length and breath and print area:

# %%
l=int(input("Enter length:"))
b=int(input("Enter breath:"))
print("Area of rectangle is:",l*b)
# Out:
# Enter length:5
# Enter breath:4
# Area of rectangle is: 20
