# %% [markdown]
# <a href="https://colab.research.google.com/github/dev8879-cyber/AIML-GenAI/blob/main/Essentials_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Arithmetic Operators:

# %%
print(2+3)
# Out:
# 5

# %%
print(4-8)
# Out:
# -4

# %%
print(20*4)
# Out:
# 80

# %%
print(23/7)
# Out:
# 3.2857142857142856

# %% [markdown]
# ###Floored division:

# %%
print(23//7)
# Out:
# 3

# %%
print(10%3)
# Out:
# 1

# %% [markdown]
# ###Power:

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# ###Calculator:

# %%
a=int(input("Enter 1st number"))
b=int(input("Enter 2nd number"))
print("Addition:",a+b);
print("Subtraction:",a-b);
print("Multiplication:",a*b);
print("Division:",a//b);
print("Modulus:",a%b);
# Out:
# Enter 1st number2
# Enter 2nd number3
# Addition: 5
# Subtraction: -1
# Multiplication: 6
# Division: 0
# Modulus: 2

# %% [markdown]
# ###Assignment operator:

# %%
x=10;
x+=2;
print(x)
# Out:
# 12

# %% [markdown]
# ###Comparision Operator:

# %%
a=5
b=30
print(a>b)
# Out:
# False

# %% [markdown]
# ###Logical operator:

# %%
a=5
b=7
print(a and b)#-->5
# Out:
# 7

# %%
print(a or b)
# Out:
# 5

# %%
not(not(print(5)))
# Out:
# 5
# False

# %% [markdown]
# ###Membership Operator:

# %%
"d" in "Devdatt"
# Out:
# True
