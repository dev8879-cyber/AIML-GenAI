# %% [markdown]
# <a href="https://colab.research.google.com/github/dev8879-cyber/AIML-GenAI/blob/main/Essentials_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Decision Making:

# %%
age=int(input("Enter age:"))
if age>=18 :
  print("Eligible to vote!")
else:
  print("Not eligible to vote!")
# Out:
# Enter age:21
# Eligible to vote!

# %%
password=input("Enter Password:")
if password=="hello@123":
  print("Welcome")
else:
  print("Incorrect password!")
# Out:
# Enter Password:hello@123
# Welcome

# %%
marks=30
if marks<30:
  print("Low")
elif (marks<=70):
  print("Avg")
else:
  print("High")
# Out:
# Avg
