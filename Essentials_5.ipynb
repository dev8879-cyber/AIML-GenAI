# %% [markdown]
# <a href="https://colab.research.google.com/github/dev8879-cyber/AIML-GenAI/blob/main/Essentials_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Write a code to to verify a person is eligible to vode or not??

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age:19

# %%
if age>18:
  print("Eligible for voting.")
else:
  print("Not eligible for voting.")
# Out:
# Eligible for voting.

# %%
n=int(input("Enter a number:"));
if (n%2==0):
  print("Given number is even.");
else:
  print("Given number is odd.");
# Out:
# Enter a number:12
# Given number is even.

# %%
n=int(input("Enter a number:"))
if n>0:
  print("Given number is positive")
elif n==0:
  print("Number is zero");
else:
  print("Number is negative")
# Out:
# Enter a number:1
# Given number is positive

# %%
a=int(input("Enter 1st number:"))
b=int(input("Enter 2nd number:"));
if a>b:
  print(a," is larger");
else:
  print(b,"is larger");
# Out:
# Enter 1st number:1
# Enter 2nd number:12
# 12 is larger

# %% [markdown]
# ###Check for BMI:

# %%
bmi=float(input("Enter BMI value:"))
if bmi<18.5:
  print("Underweight");
elif bmi<=24.9:
  ptint("Normal weight")
elif bmi<=29.9:
  print("Overweight")
else:
  print("obese");
# Out:
# Enter BMI value:30
# obese

# %% [markdown]
# ###Check for divisibility:

# %%
n=int(input("Enter the number:"))
if n%3==0 and n%5==0:
  print("Divisible by both 3 and 5")
elif n%3==0:
  print("Only divisible by 3")
elif n%5==0:
  print("Only divisible by 5")
else:
  print("Neither divisible by 3 or 5")
# Out:
# Enter the number:15
# Divisible by both 3 and 5

# %% [markdown]
# ##Loops:

# %%
#Printing "Hi" 10 times:
for i in range(10):
  print("Hi")
  i=i-1;
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
